# %%
import spacy
import pprint
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
text = "European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices"
doc = nlp(unicode(text))

# %%
pp = pprint.PrettyPrinter(indent=4)
pp.pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [   (u'European', u'NORP'),
#     (u'Google', u'ORG'),
#     (u'$5.1 billion', u'MONEY'),
#     (u'Wednesday', u'DATE')]

# %%
pp.pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [   (European, u'B', u'NORP'),
#     (authorities, u'O', u''),
#     (fined, u'O', u''),
#     (Google, u'B', u'ORG'),
#     (a, u'O', u''),
#     (record, u'O', u''),
#     ($, u'B', u'MONEY'),
#     (5.1, u'I', u'MONEY'),
#     (billion, u'I', u'MONEY'),
#     (on, u'O', u''),
#     (Wednesday, u'B', u'DATE'),
#     (for, u'O', u''),
#     (abusing, u'O', u''),
#     (its, u'O', u''),
#     (power, u'O', u''),
#     (in, u'O', u''),
#     (the, u'O', u''),
#     (mobile, u'O', u''),
#     (phone, u'O', u''),
#     (market, u'O', u''),
#     (and, u'O', u''),
#     (ordered, u'O', u''),
#     (the, u'O', u''),
#     (company, u'O', u''),
#     (to, u'O', u''),
#     (alter, u'O', u''),
#     (its, u'O', u''),
#     (practices, u'O', u'')]

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8e0077bd7505> in <module>()
# ----> 1 labels = [x.label_ for x in article.ents]
#       2 Counter(labels)
#
# NameError: name 'article' is not defined

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  authorities fined
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  a record
# ...

# %%
displacy.render(doc, style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="3410" height="557" style="max-width: none; height: 557px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467">
#     <tspan class="displacy-word" fill="currentColor" x="50">European</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467">
#     <tspan class="displacy-word" fill="currentColor" x="170">authorities</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467">
#     <tspan class="displacy-word" fill="currentColor" x="290">fined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# ...

# %%
## Longer Text
import urllib
target_url = 'https://www.theguardian.com/us-news/2019/feb/03/ronny-jackson-trump-makes-controversial-doctor-his-chief-medical-adviser'
txt = urllib.urlopen(target_url).read()

# %%
text = "President Donald Trump has appointed his former doctor to be his assistant and chief medical adviser.ed him to head the Veterans Affairs department.Trump calls for Senator Jon Tester to resign over Ronny Jackson claims.The navy doctor withdrew following allegations of professional misconduct, which the Pentagon continues to investigate. Jackson has denied any wrongdoing.After Trump nominated Jackson for the position last April, Montana Democrat Jon Tester released a document summarizing more than 20 interviews conducted by staffers with people who served with Jackson. The document included allegations of drunkenness, faulty prescribing practices and creating a hostile work environment."
doc = nlp(unicode(text))

pp = pprint.PrettyPrinter(indent=4)
pp.pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [   (u'Donald Trump', u'PERSON'),
#     (u'Veterans Affairs', u'ORG'),
#     (u'Jon Tester', u'PERSON'),
#     (u'Ronny Jackson', u'PERSON'),
#     (u'Pentagon', u'ORG'),
#     (u'Jackson', u'PERSON'),
#     (u'Trump', u'PERSON'),
#     (u'Jackson', u'PERSON'),
#     (u'last April', u'DATE'),
#     (u'Montana', u'GPE'),
#     (u'Democrat', u'NORP'),
#     (u'Jon Tester', u'PERSON'),
#     (u'more than 20', u'CARDINAL'),
#     (u'Jackson', u'PERSON')]

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has appointed his former doctor to be his assistant and chief medical adviser.ed him to head the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Veterans Affairs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...
